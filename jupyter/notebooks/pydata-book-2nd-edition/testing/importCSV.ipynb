# %%
import numpy as np
from numpy import nan as NA
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %%
df = pd.read_csv('costmanagementexport.csv')
df.head()
# Out:
#   invoiceId  previousInvoiceId                      billingAccountId  \
# 0         ﻿                NaN  7c3f9612-634e-51f8-a7b7-1c7cff3311c3
# 1       NaN                NaN  7c3f9612-634e-51f8-a7b7-1c7cff3311c3
# 2       NaN                NaN  7c3f9612-634e-51f8-a7b7-1c7cff3311c3
# 3       NaN                NaN  7c3f9612-634e-51f8-a7b7-1c7cff3311c3
# 4       NaN                NaN  7c3f9612-634e-51f8-a7b7-1c7cff3311c3
#
#   billingAccountName   billingProfileId billingProfileName   invoiceSectionId  \
# 0         Thor Jarle  EBD3-3RUH-BG7-PGB  Billing Profile 2  7O36-VX7O-PJA-PGB
# 1         Thor Jarle  EBD3-3RUH-BG7-PGB  Billing Profile 2  7O36-VX7O-PJA-PGB
# 2         Thor Jarle  EBD3-3RUH-BG7-PGB  Billing Profile 2  7O36-VX7O-PJA-PGB
# 3         Thor Jarle  EBD3-3RUH-BG7-PGB  Billing Profile 2  7O36-VX7O-PJA-PGB
# 4         Thor Jarle  EBD3-3RUH-BG7-PGB  Billing Profile 2  7O36-VX7O-PJA-PGB
#
#    invoiceSectionName  resellerName  resellerMpnId  ...   frequency  term  \
# 0  Thor Jarle Kinstad           NaN            NaN  ...  UsageBased   NaN
# 1  Thor Jarle Kinstad           NaN            NaN  ...  UsageBased   NaN
# 2  Thor Jarle Kinstad           NaN            NaN  ...  UsageBased   NaN
# 3  Thor Jarle Kinstad           NaN            NaN  ...  UsageBased   NaN
# 4  Thor Jarle Kinstad           NaN            NaN  ...  UsageBased   NaN
#
#    reservationId reservationName pricingModel unitPrice  \
# 0            NaN             NaN     OnDemand  0.500000
# 1            NaN             NaN     OnDemand  0.000396
# 2            NaN             NaN     OnDemand  0.500000
# 3            NaN             NaN     OnDemand  0.004730
# 4            NaN             NaN     OnDemand  0.400000
#
#   costAllocationRuleName benefitId benefitName provider
# 0                    NaN       NaN         NaN    Azure
# 1                    NaN       NaN         NaN    Azure
# 2                    NaN       NaN         NaN    Azure
# 3                    NaN       NaN         NaN    Azure
# 4                    NaN       NaN         NaN    Azure
#
# [5 rows x 65 columns]

# %%
billingProfile = pd.Series(df['billingProfileName'])
billingProfile.drop_duplicates()
# Out:
# 0      Billing Profile 2
# 235    Billing Profile 1
# Name: billingProfileName, dtype: object

# %%
count = 0
for x in df['billingAccountName']: 
    if x == 'Thor Jarle':
        count += 0
    else:
        count += 1

count
# Out:
# 0
